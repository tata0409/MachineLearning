# %% [markdown]
# #Модель	                   Контекст (токени)	           Приблизно в словах
# * gemini        -             1 million,                     about 750000 words
# * claude         -            200000,                        about 150000 words
# * grok - 256000, about 192000 words
# * DeepSeek - 64000, about 48000 words
