# %% [markdown]
# <a href="https://colab.research.google.com/github/tata0409/MachineLearning/blob/main/HugginFaceProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
from datasets import Dataset

data = [
    {"prompt": "What's gravitational force?", "response":"Gravitational force is the attraction force between two bodies with mass."},
    {"prompt": "Explain buoyant force", "response":"Buoyant force is the upward push a fluid exerts on an object immersed in it, equal to the weight of the fluid the object displaces."},
    {"prompt": "What's the difference between kinetic and potential energy?", "response":"Kinetic energy is caused by movement of the object, while potential energy is stored inside the object."},
    {"prompt": "What does DB stand for?", "response":"DB stands for Data Base"},
    {"prompt": "What is mathematical statistics?", "response":"Science that analyzes data about a certain object or event."},
    {"prompt": "What is function signature?", "response":"Function signature is the identifier of a function, contaning it's name return type and list of parameters"},
    {"prompt": "", "response":""},
    {"prompt": "", "response":""},
    {"prompt": "", "response":""},
]

for item in data:
  item['text'] = item['prompt'].strip()+"\nAnswer: "+item['response'].strip()

dataset = Dataset.from_list([{"text": d['text']} for d in data])

model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
def tokenize_fn(examples):
  tokens = tokenizer(examples["text"], truncation=True, padding = "max_length", max_length = 128)
  #tokens['labels'] =
